# %% [markdown]
# # Proyek Analisis Data: Air Quality Dataset
# - **Nama:** Ahmad Raja Fadhil
# - **Email:** ikefadhil99@gmail.com
# - **ID Dicoding:** ahmad_raja_11

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# Pada bagian ini, terdapat 2 buah pertanyaan bisnis yang akan dicari solusinya melalui analisis data yang akan dilakukan

# %% [markdown]
# - Kota manakah yang memiliki konsentrasi CO paling tinggi dan paling rendah pada 2017?
# - Apakah konsentrasi curah hujan berpengaruh terhadap konsentrasi CO?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %% [markdown]
# Bagian ini berisi library yang akan digunakan untuk mengolah dataset

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# Bagian ini adalah yang digunakan untuk mengumpulkan dataset yang akan di analisa

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-823de62c-f781-44f3-bdbb-3144f9d0aee0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-823de62c-f781-44f3-bdbb-3144f9d0aee0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
aoti = pd.read_csv("PRSA_Data_Aotizhongxin_20130301-20170228.csv")
aoti.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
changping = pd.read_csv("PRSA_Data_Changping_20130301-20170228.csv")
changping.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %%
dingling = pd.read_csv("PRSA_Data_Dingling_20130301-20170228.csv")
dingling.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0  82.0  -2.3
# 1   2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0  80.0  -2.5
# 2   3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0  79.0  -3.0
# 3   4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0  79.0  -3.6
# 4   5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1020.8 -19.7   0.0    E   0.5  Dingling
# 1  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4  1022.3 -19.4   0.0    N   2.1  Dingling

# %%
dongsi = pd.read_csv("PRSA_Data_Dongsi_20130301-20170228.csv")
dongsi.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  3.0  17.0  300.0  89.0  -0.5
# 1   2  2013      3    1     1    4.0   4.0  3.0  16.0  300.0  88.0  -0.7
# 2   3  2013      3    1     2    7.0   7.0  NaN  17.0  300.0  60.0  -1.2
# 3   4  2013      3    1     3    3.0   3.0  5.0  18.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0   3.0  7.0   NaN  200.0  84.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4  1027.1 -24.5   0.0  NNW   3.2  Dongsi

# %%
guanyuan = pd.read_csv("PRSA_Data_Guanyuan_20130301-20170228.csv")
guanyuan.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  14.0  20.0  300.0  69.0  -0.7
# 1   2  2013      3    1     1    4.0   4.0  13.0  17.0  300.0  72.0  -1.1
# 2   3  2013      3    1     2    3.0   3.0  10.0  19.0  300.0  69.0  -1.1
# 3   4  2013      3    1     3    3.0   6.0   7.0  24.0  400.0  62.0  -1.4
# 4   5  2013      3    1     4    3.0   6.0   5.0  14.0  400.0  71.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1023.0 -18.8   0.0  NNW   4.4  Guanyuan
# 1  1023.2 -18.2   0.0    N   4.7  Guanyuan
# 2  1023.5 -18.2   0.0  NNW   5.6  Guanyuan
# 3  1024.5 -19.4   0.0   NW   3.1  Guanyuan
# 4  1025.2 -19.5   0.0    N   2.0  Guanyuan

# %%
gucheng = pd.read_csv("PRSA_Data_Gucheng_20130301-20170228.csv")
gucheng.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0  18.0  5.0  NaN  800.0  88.0   0.1
# 1   2  2013      3    1     1    6.0  15.0  5.0  NaN  800.0  88.0  -0.3
# 2   3  2013      3    1     2    5.0  18.0  NaN  NaN  700.0  52.0  -0.7
# 3   4  2013      3    1     3    6.0  20.0  6.0  NaN    NaN   NaN  -1.0
# 4   5  2013      3    1     4    5.0  17.0  5.0  NaN  600.0  73.0  -1.3
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1021.1 -18.6   0.0   NW   4.4  Gucheng
# 1  1021.5 -19.0   0.0   NW   4.0  Gucheng
# 2  1021.5 -19.8   0.0  WNW   4.6  Gucheng
# 3  1022.7 -21.2   0.0    W   2.8  Gucheng
# 4  1023.0 -21.4   0.0  WNW   3.6  Gucheng

# %%
huairou = pd.read_csv("PRSA_Data_Huairou_20130301-20170228.csv")
huairou.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    7.0   7.0  3.0  2.0  100.0  91.0  -2.3
# 1   2  2013      3    1     1    4.0   4.0  3.0  NaN  100.0  92.0  -2.7
# 2   3  2013      3    1     2    4.0   4.0  NaN  NaN  100.0  91.0  -3.2
# 3   4  2013      3    1     3    3.0   3.0  3.0  2.0    NaN   NaN  -3.3
# 4   5  2013      3    1     4    3.0   3.0  7.0  NaN  300.0  86.0  -4.1
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1020.3 -20.7   0.0  WNW   3.1  Huairou
# 1  1020.8 -20.5   0.0  NNW   1.5  Huairou
# 2  1020.6 -21.4   0.0   NW   1.8  Huairou
# 3  1021.3 -23.7   0.0  NNW   2.4  Huairou
# 4  1022.1 -22.7   0.0  NNW   2.2  Huairou

# %%
nong = pd.read_csv("PRSA_Data_Nongzhanguan_20130301-20170228.csv")
nong.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    5.0  14.0  4.0  12.0  200.0  85.0  -0.5
# 1   2  2013      3    1     1    8.0  12.0  6.0  14.0  200.0  84.0  -0.7
# 2   3  2013      3    1     2    3.0   6.0  5.0  14.0  200.0  83.0  -1.2
# 3   4  2013      3    1     3    5.0   5.0  5.0  14.0  200.0  84.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  6.0  21.0  200.0  77.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1024.5 -21.4   0.0  NNW   5.7  Nongzhanguan
# 1  1025.1 -22.1   0.0   NW   3.9  Nongzhanguan
# 2  1025.3 -24.6   0.0  NNW   5.3  Nongzhanguan
# 3  1026.2 -25.5   0.0    N   4.9  Nongzhanguan
# 4  1027.1 -24.5   0.0  NNW   3.2  Nongzhanguan

# %%
shunyi = pd.read_csv("PRSA_Data_Shunyi_20130301-20170228.csv")
shunyi.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  3.0  8.0  300.0  44.0  -0.9
# 1   2  2013      3    1     1   12.0  12.0  3.0  7.0  300.0  47.0  -1.1
# 2   3  2013      3    1     2   14.0  14.0  NaN  7.0  200.0  22.0  -1.7
# 3   4  2013      3    1     3   12.0  12.0  3.0  5.0    NaN   NaN  -2.1
# 4   5  2013      3    1     4   12.0  12.0  3.0  NaN  200.0  11.0  -2.4
#
#      PRES  DEWP  RAIN  wd  WSPM station
# 0  1025.8 -20.5   0.0  NW   9.3  Shunyi
# 1  1026.1 -21.3   0.0  NW   9.4  Shunyi
# 2  1026.2 -23.0   0.0  NW   8.6  Shunyi
# 3  1027.3 -23.3   0.0  NW   6.6  Shunyi
# 4  1027.7 -22.9   0.0  NW   4.5  Shunyi

# %%
tiantan = pd.read_csv("PRSA_Data_Tiantan_20130301-20170228.csv")
tiantan.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0   6.0  4.0   8.0  300.0  81.0  -0.5
# 1   2  2013      3    1     1    6.0  29.0  5.0   9.0  300.0  80.0  -0.7
# 2   3  2013      3    1     2    6.0   6.0  4.0  12.0  300.0  75.0  -1.2
# 3   4  2013      3    1     3    6.0   6.0  4.0  12.0  300.0  74.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  7.0  15.0  400.0  70.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1024.5 -21.4   0.0  NNW   5.7  Tiantan
# 1  1025.1 -22.1   0.0   NW   3.9  Tiantan
# 2  1025.3 -24.6   0.0  NNW   5.3  Tiantan
# 3  1026.2 -25.5   0.0    N   4.9  Tiantan
# 4  1027.1 -24.5   0.0  NNW   3.2  Tiantan

# %%
wanliu = pd.read_csv("PRSA_Data_Wanliu_20130301-20170228.csv")
wanliu.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    8.0   8.0  6.0  28.0  400.0  52.0  -0.7
# 1   2  2013      3    1     1    9.0   9.0  6.0  28.0  400.0  50.0  -1.1
# 2   3  2013      3    1     2    3.0   6.0  NaN  19.0  400.0  55.0  -1.1
# 3   4  2013      3    1     3   11.0  30.0  8.0  14.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0  13.0  9.0   NaN  300.0  54.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1023.0 -18.8   0.0  NNW   4.4  Wanliu
# 1  1023.2 -18.2   0.0    N   4.7  Wanliu
# 2  1023.5 -18.2   0.0  NNW   5.6  Wanliu
# 3  1024.5 -19.4   0.0   NW   3.1  Wanliu
# 4  1025.2 -19.5   0.0    N   2.0  Wanliu

# %%
wans = pd.read_csv("PRSA_Data_Wanshouxigong_20130301-20170228.csv")
wans.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  6.0  17.0  200.0  62.0   0.3
# 1   2  2013      3    1     1   11.0  11.0  7.0  14.0  200.0  66.0  -0.1
# 2   3  2013      3    1     2    8.0   8.0  NaN  16.0  200.0  59.0  -0.6
# 3   4  2013      3    1     3    8.0   8.0  3.0  16.0    NaN   NaN  -0.7
# 4   5  2013      3    1     4    8.0   8.0  3.0   NaN  300.0  36.0  -0.9
#
#      PRES  DEWP  RAIN   wd  WSPM        station
# 0  1021.9 -19.0   0.0  WNW   2.0  Wanshouxigong
# 1  1022.4 -19.3   0.0  WNW   4.4  Wanshouxigong
# 2  1022.6 -19.7   0.0  WNW   4.7  Wanshouxigong
# 3  1023.5 -20.9   0.0   NW   2.6  Wanshouxigong
# 4  1024.1 -21.7   0.0  WNW   2.5  Wanshouxigong

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Bagian untuk memeriksa bagian yang kosong atau NaN pada dataset yang digunakan

# %%
aoti = pd.read_csv("PRSA_Data_Aotizhongxin_20130301-20170228.csv")
aoti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
print("Jumlah null: ")
aoti.isnull().sum()
# Out:
# Jumlah null:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", aoti.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
aoti.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34139.000000  34346.000000  34129.000000  34041.000000  33288.000000
# mean      82.773611    110.060391     17.375901     59.305833   1262.945145
# ...

# %%
changping = pd.read_csv("PRSA_Data_Changping_20130301-20170228.csv")
changping.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
print("Jumlah null: ")
changping.isnull().sum()
# Out:
# Jumlah null:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       774
# PM10        582
# SO2         628
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", changping.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
changping.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34290.000000  34482.000000  34436.000000  34397.000000  33543.000000
# mean      71.099743     94.657871     14.958906     44.182086   1152.301345
# ...

# %%
dingling = pd.read_csv("PRSA_Data_Dingling_20130301-20170228.csv")
dingling.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34285 non-null  float64
#  6   PM10     34408 non-null  float64
#  7   SO2      34334 non-null  float64
#  8   NO2      33830 non-null  float64
#  9   CO       33052 non-null  float64
#  10  O3       33850 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
print("Jumlah null: ")
dingling.isnull().sum()
# Out:
# Jumlah null:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       779
# PM10        656
# SO2         730
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", dingling.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
dingling.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34285.000000  34408.000000  34334.000000  33830.000000  33052.000000
# mean      65.989497     83.739723     11.749650     27.585467    904.896073
# ...

# %%
dongsi = pd.read_csv("PRSA_Data_Dongsi_20130301-20170228.csv")
dongsi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34314 non-null  float64
#  6   PM10     34511 non-null  float64
#  7   SO2      34401 non-null  float64
#  8   NO2      33463 non-null  float64
#  9   CO       31867 non-null  float64
#  10  O3       34400 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
print("Jumlah null: ")
dongsi.isnull().sum()
# Out:
# Jumlah null:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       750
# PM10        553
# SO2         663
# NO2        1601
# CO         3197
# O3          664
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", dongsi.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
dongsi.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34314.000000  34511.000000  34401.000000  33463.000000  31867.000000
# mean      86.194297    110.336742     18.531107     53.699443   1330.069131
# ...

# %%
guanyuan = pd.read_csv("PRSA_Data_Guanyuan_20130301-20170228.csv")
guanyuan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34448 non-null  float64
#  6   PM10     34635 non-null  float64
#  7   SO2      34590 non-null  float64
#  8   NO2      34405 non-null  float64
#  9   CO       33311 non-null  float64
#  10  O3       33891 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
print("Jumlah null: ")
guanyuan.isnull().sum()
# Out:
# Jumlah null:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       616
# PM10        429
# SO2         474
# NO2         659
# CO         1753
# O3         1173
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", guanyuan.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
guanyuan.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34448.000000  34635.000000  34590.000000  34405.000000  33311.000000
# mean      82.933372    109.023303     17.590941     57.901643   1271.294377
# ...

# %%
gucheng = pd.read_csv("PRSA_Data_Gucheng_20130301-20170228.csv")
gucheng.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34418 non-null  float64
#  6   PM10     34683 non-null  float64
#  7   SO2      34557 non-null  float64
#  8   NO2      34396 non-null  float64
#  9   CO       33663 non-null  float64
#  10  O3       34335 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35013 non-null  float64
#  14  RAIN     35021 non-null  float64
#  15  wd       34905 non-null  object
#  16  WSPM     35022 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
print("Jumlah null: ")
gucheng.isnull().sum()
# Out:
# Jumlah null:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       646
# PM10        381
# SO2         507
# NO2         668
# CO         1401
# O3          729
# TEMP         51
# PRES         50
# DEWP         51
# RAIN         43
# wd          159
# WSPM         42
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", gucheng.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
gucheng.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34418.000000  34683.000000  34557.000000  34396.000000  33663.000000
# mean      83.852089    118.861978     15.366162     55.871075   1323.974423
# ...

# %%
huairou = pd.read_csv("PRSA_Data_Huairou_20130301-20170228.csv")
huairou.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34111 non-null  float64
#  6   PM10     34287 non-null  float64
#  7   SO2      34084 non-null  float64
#  8   NO2      33425 non-null  float64
#  9   CO       33642 non-null  float64
#  10  O3       33913 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35011 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35009 non-null  float64
#  15  wd       34762 non-null  object
#  16  WSPM     35015 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
print("Jumlah null: ")
huairou.isnull().sum()
# Out:
# Jumlah null:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       953
# PM10        777
# SO2         980
# NO2        1639
# CO         1422
# O3         1151
# TEMP         51
# PRES         53
# DEWP         53
# RAIN         55
# wd          302
# WSPM         49
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", huairou.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
huairou.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34111.000000  34287.000000  34084.000000  33425.000000  33642.000000
# mean      69.626367     91.482690     12.121553     32.497250   1022.554545
# ...

# %%
nong = pd.read_csv("PRSA_Data_Nongzhanguan_20130301-20170228.csv")
nong.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34436 non-null  float64
#  6   PM10     34624 non-null  float64
#  7   SO2      34618 non-null  float64
#  8   NO2      34372 non-null  float64
#  9   CO       33858 non-null  float64
#  10  O3       34558 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
print("Jumlah null: ")
nong.isnull().sum()
# Out:
# Jumlah null:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       628
# PM10        440
# SO2         446
# NO2         692
# CO         1206
# O3          506
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", nong.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
nong.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34436.000000  34624.000000  34618.000000  34372.000000  33858.000000
# mean      84.838483    108.991096     18.689242     58.097172   1324.350198
# ...

# %%
shunyi = pd.read_csv("PRSA_Data_Shunyi_20130301-20170228.csv")
shunyi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34151 non-null  float64
#  6   PM10     34516 non-null  float64
#  7   SO2      33768 non-null  float64
#  8   NO2      33699 non-null  float64
#  9   CO       32886 non-null  float64
#  10  O3       33575 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35013 non-null  float64
#  13  DEWP     35010 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34581 non-null  object
#  16  WSPM     35020 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
print("Jumlah null: ")
shunyi.isnull().sum()
# Out:
# Jumlah null:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       913
# PM10        548
# SO2        1296
# NO2        1365
# CO         2178
# O3         1489
# TEMP         51
# PRES         51
# DEWP         54
# RAIN         51
# wd          483
# WSPM         44
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", shunyi.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
shunyi.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34151.000000  34516.000000  33768.000000  33699.000000  32886.000000
# mean      79.491602     98.737026     13.572039     43.908865   1187.063979
# ...

# %%
tiantan = pd.read_csv("PRSA_Data_Tiantan_20130301-20170228.csv")
tiantan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34387 non-null  float64
#  6   PM10     34467 non-null  float64
#  7   SO2      33946 non-null  float64
#  8   NO2      34320 non-null  float64
#  9   CO       33938 non-null  float64
#  10  O3       34221 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
print("Jumlah null: ")
tiantan.isnull().sum()
# Out:
# Jumlah null:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       677
# PM10        597
# SO2        1118
# NO2         744
# CO         1126
# O3          843
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", tiantan.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
tiantan.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34387.000000  34467.000000  33946.000000  34320.000000  33938.000000
# mean      82.164911    106.363672     14.367615     53.162646   1298.303318
# ...

# %%
wanliu = pd.read_csv("PRSA_Data_Wanliu_20130301-20170228.csv")
wanliu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34682 non-null  float64
#  6   PM10     34780 non-null  float64
#  7   SO2      34489 non-null  float64
#  8   NO2      33994 non-null  float64
#  9   CO       33252 non-null  float64
#  10  O3       32957 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34941 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
print("Jumlah null: ")
wanliu.isnull().sum()
# Out:
# Jumlah null:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       382
# PM10        284
# SO2         575
# NO2        1070
# CO         1812
# O3         2107
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd          123
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", wanliu.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
wanliu.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34682.000000  34780.000000  34489.000000  33994.000000  33252.000000
# mean      83.374716    110.464618     18.376481     65.258789   1319.353513
# ...

# %%
wans = pd.read_csv("PRSA_Data_Wanshouxigong_20130301-20170228.csv")
wans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34368 non-null  float64
#  6   PM10     34580 non-null  float64
#  7   SO2      34395 non-null  float64
#  8   NO2      34310 non-null  float64
#  9   CO       33767 non-null  float64
#  10  O3       33986 non-null  float64
#  11  TEMP     35045 non-null  float64
#  12  PRES     35045 non-null  float64
#  13  DEWP     35045 non-null  float64
#  14  RAIN     35045 non-null  float64
#  15  wd       34985 non-null  object
#  16  WSPM     35051 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
print("jumlah null: ")
wans.isnull().sum()
# Out:
# jumlah null:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       696
# PM10        484
# SO2         669
# NO2         754
# CO         1297
# O3         1078
# TEMP         19
# PRES         19
# DEWP         19
# RAIN         19
# wd           79
# WSPM         13
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", wans.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
wans.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2          NO2            CO  \
# count  34368.000000  34580.000000  34395.000000  34310.00000  33767.000000
# mean      85.024136    112.223459     17.148603     55.52956   1370.395031
# ...

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Bagian untuk membersihkan dataset dari hal yang tidak perlu dan mengisi kolom yang bernilai NaN

# %% [markdown]
# Kota Aotizhongxin

# %%
aoti.drop(columns=['No'], inplace=True)
aoti[aoti.CO.isna()]
# Out:
#        year  month  day  hour  PM2.5   PM10       SO2       NO2  CO    O3  \
# 75     2013      3    4     3   12.0   34.0    6.0000   12.0000 NaN  77.0
# 124    2013      3    6     4  192.0  203.0   83.6808  140.4252 NaN  22.0
# 171    2013      3    8     3  324.0  373.0   71.0000  154.0000 NaN  84.0
# 178    2013      3    8    10  326.0  844.0  125.9496  179.2269 NaN  84.0
# 267    2013      3   12     3  117.0  127.0   73.0000   81.0000 NaN  47.0
# ...     ...    ...  ...   ...    ...    ...       ...       ...  ..   ...
# 34885  2017      2   21    13    NaN    NaN       NaN       NaN NaN   NaN
# 34912  2017      2   22    16  131.0  131.0       NaN   95.0000 NaN  47.0
# 35027  2017      2   27    11  122.0  122.0       NaN       NaN NaN  42.0
# 35028  2017      2   27    12    NaN    NaN       NaN       NaN NaN   NaN
# 35029  2017      2   27    13    NaN    NaN       NaN       NaN NaN   NaN
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM       station
# ...

# %%
aoti.dropna(subset=['CO', 'RAIN'], inplace=True)

# %%
aoti.CO.value_counts()
# Out:
# 400.0     2877
# 500.0     2728
# 300.0     2578
# 600.0     2561
# 700.0     2349
#           ...
# 9200.0       2
# 9300.0       1
# 3899.0       1
# 4599.0       1
# 5599.0       1
# Name: CO, Length: 112, dtype: int64

# %%
aoti.fillna(value="NaN", inplace=True)
aoti.isna().sum()
# Out:
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Kota Changping

# %%
changping.drop(columns=['No'], inplace=True)
changping[changping.CO.isna()]
# Out:
#        year  month  day  hour  PM2.5   PM10      SO2      NO2  CO    O3  TEMP  \
# 27     2013      3    2     3   14.0   24.0  23.0000  42.0000 NaN   NaN  -2.5
# 123    2013      3    6     3  170.0  179.0  55.0000  74.0000 NaN  81.0   3.7
# 178    2013      3    8    10  180.0  257.0  59.4048  94.0274 NaN  65.0  17.3
# 219    2013      3   10     3    3.0    7.0   9.0000  24.0000 NaN  94.0   4.1
# 315    2013      3   14     3   80.0   88.0  23.0000  69.0000 NaN  92.0   0.0
# ...     ...    ...  ...   ...    ...    ...      ...      ...  ..   ...   ...
# 34880  2017      2   21     8    NaN    NaN      NaN      NaN NaN   NaN  -1.8
# 34883  2017      2   21    11    NaN    NaN      NaN      NaN NaN   NaN  -0.5
# 34885  2017      2   21    13    NaN    NaN      NaN      NaN NaN   NaN  -1.0
# 34887  2017      2   21    15    NaN    6.0      NaN  34.0000 NaN   2.0  -2.1
# 35058  2017      2   28    18   18.0   57.0      NaN   2.0000 NaN   2.0  13.4
#
# ...

# %%
changping.dropna(subset=['CO', 'RAIN'], inplace=True)

# %%
changping.CO.value_counts()
# Out:
# 500.0     3193
# 400.0     3170
# 600.0     2800
# 300.0     2763
# 700.0     2477
#           ...
# 5299.0       1
# 6299.0       1
# 9800.0       1
# 4099.0       1
# 9700.0       1
# Name: CO, Length: 115, dtype: int64

# %%
changping.fillna(value="NaN", inplace=True)
changping.isna().sum()
# Out:
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Kota Dingling

# %%
dingling.drop(columns=['No'], inplace=True)
dingling[dingling.CO.isna()]
# Out:
#        year  month  day  hour  PM2.5   PM10      SO2      NO2  CO     O3  \
# 51     2013      3    3     3   57.0   57.0  20.0000  67.0000 NaN   45.0
# 147    2013      3    7     3   91.0   85.0  32.0000  46.0000 NaN   52.0
# 178    2013      3    8    10  122.0  175.0  31.7016  50.0932 NaN   75.0
# 243    2013      3   11     3   75.0   83.0  18.0000  34.0000 NaN  100.0
# 252    2013      3   11    12  113.0  153.0  58.0000  68.0000 NaN  100.0
# ...     ...    ...  ...   ...    ...    ...      ...      ...  ..    ...
# 34866  2017      2   20    18    NaN    NaN      NaN      NaN NaN    NaN
# 34883  2017      2   21    11    NaN    NaN  26.0000  68.0000 NaN    5.0
# 34884  2017      2   21    12   62.0   62.0      NaN  53.0000 NaN    NaN
# 34885  2017      2   21    13    NaN    NaN      NaN      NaN NaN    NaN
# 35056  2017      2   28    16   14.0   30.0      NaN   6.0000 NaN   93.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM   station
# ...

# %%
dingling.dropna(subset=['CO', 'RAIN'], inplace=True)

# %%
dingling.CO.value_counts()
# Out:
# 200.0     4125
# 300.0     3627
# 400.0     3195
# 500.0     2671
# 600.0     2242
#           ...
# 350.0        1
# 1150.0       1
# 150.0        1
# 9000.0       1
# 6600.0       1
# Name: CO, Length: 103, dtype: int64

# %%
dingling.fillna(value="NaN", inplace=True)
dingling.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Kota Dongsi

# %%
dongsi.drop(columns=['No'], inplace=True)
dongsi[dongsi.CO.isna()]
# Out:
#        year  month  day  hour  PM2.5   PM10      SO2       NO2  CO     O3  \
# 3      2013      3    1     3    3.0    3.0   5.0000   18.0000 NaN    NaN
# 74     2013      3    4     2   43.0   48.0   6.2832   20.1194 NaN   94.0
# 99     2013      3    5     3  104.0  136.0  71.0000   78.0000 NaN  102.0
# 178    2013      3    8    10  260.0  197.0  81.1104  191.3396 NaN  107.0
# 195    2013      3    9     3   74.0   98.0  52.0000   89.0000 NaN   99.0
# ...     ...    ...  ...   ...    ...    ...      ...       ...  ..    ...
# 34890  2017      2   21    18   32.0   37.0      NaN       NaN NaN   26.0
# 35030  2017      2   27    14    NaN    NaN      NaN       NaN NaN    NaN
# 35031  2017      2   27    15    NaN    NaN      NaN       NaN NaN    NaN
# 35032  2017      2   27    16    NaN    NaN      NaN       NaN NaN    NaN
# 35033  2017      2   27    17    NaN    NaN      NaN       NaN NaN    NaN
#
#        TEMP    PRES  DEWP  RAIN  wd  WSPM station
# ...

# %%
dongsi.dropna(subset=['CO', 'RAIN'], inplace=True)

# %%
dongsi.CO.value_counts()
# Out:
# 300.0     2419
# 400.0     2136
# 700.0     2074
# 600.0     2048
# 500.0     1978
#           ...
# 6599.0       1
# 5299.0       1
# 5099.0       1
# 4599.0       1
# 9800.0       1
# Name: CO, Length: 115, dtype: int64

# %%
dongsi.fillna(value="NaN", inplace=True)
dongsi.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Kotan Guanyuan

# %%
guanyuan.drop(columns=['No'], inplace=True)
guanyuan[guanyuan.CO.isna()]
# Out:
#        year  month  day  hour  PM2.5   PM10       SO2       NO2  CO     O3  \
# 27     2013      3    2     3    3.0    6.0   12.0000   32.0000 NaN   79.0
# 123    2013      3    6     3  160.0  189.0  102.0000  160.0000 NaN   39.0
# 178    2013      3    8    10  314.0  331.0   72.5424  220.0816 NaN  107.0
# 219    2013      3   10     3   16.0   30.0   14.0000   46.0000 NaN   87.0
# 315    2013      3   14     3   48.0   52.0   25.0000   52.0000 NaN   82.0
# ...     ...    ...  ...   ...    ...    ...       ...       ...  ..    ...
# 35043  2017      2   28     3    NaN    NaN       NaN       NaN NaN    NaN
# 35044  2017      2   28     4    NaN    NaN       NaN       NaN NaN    NaN
# 35045  2017      2   28     5    NaN    NaN       NaN       NaN NaN    NaN
# 35046  2017      2   28     6    NaN    NaN       NaN       NaN NaN    NaN
# 35047  2017      2   28     7    NaN    NaN       NaN       NaN NaN    NaN
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM   station
# ...

# %%
guanyuan.dropna(subset=['CO', 'RAIN'], inplace=True)

# %%
guanyuan.CO.value_counts()
# Out:
# 400.0     2417
# 300.0     2341
# 600.0     2330
# 500.0     2299
# 700.0     2218
#           ...
# 6799.0       1
# 9600.0       1
# 4299.0       1
# 9900.0       1
# 6299.0       1
# Name: CO, Length: 117, dtype: int64

# %%
guanyuan.fillna(value="NaN", inplace=True)
guanyuan.isna().sum()
# Out:
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Kota Gucheng

# %%
gucheng.drop(columns=['No'], inplace=True)
gucheng[gucheng.CO.isna()]
# Out:
#        year  month  day  hour  PM2.5   PM10       SO2       NO2  CO     O3  \
# 3      2013      3    1     3    6.0   20.0    6.0000       NaN NaN    NaN
# 99     2013      3    5     3  122.0  157.0   53.0000   70.0000 NaN  107.0
# 111    2013      3    5    15  133.0  137.0   66.0000       NaN NaN  107.0
# 136    2013      3    6    16  162.0  288.0  155.0000  153.0000 NaN   20.0
# 178    2013      3    8    10  266.0  329.0   83.1096  179.2269 NaN  107.0
# ...     ...    ...  ...   ...    ...    ...       ...       ...  ..    ...
# 34914  2017      2   22    18    NaN    NaN       NaN       NaN NaN    NaN
# 34934  2017      2   23    14   21.0   49.0       NaN   20.0000 NaN   70.0
# 34935  2017      2   23    15   29.0   34.0       NaN   16.0000 NaN    NaN
# 34936  2017      2   23    16   30.0   57.0       NaN       NaN NaN   69.0
# 34937  2017      2   23    17   37.0   37.0       NaN       NaN NaN   69.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM  station
# ...

# %%
gucheng.dropna(subset=['CO', 'RAIN'], inplace=True)

# %%
gucheng.CO.value_counts()
# Out:
# 300.0     2628
# 600.0     2373
# 400.0     2325
# 700.0     2320
# 500.0     2272
#           ...
# 5299.0       1
# 9500.0       1
# 6099.0       1
# 6299.0       1
# 7800.0       1
# Name: CO, Length: 116, dtype: int64

# %%
gucheng.fillna(value="NaN", inplace=True)
gucheng.isna().sum()
# Out:
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Kota Huairou

# %%
huairou.drop(columns=['No'], inplace=True)
huairou[huairou.CO.isna()]
# Out:
#        year  month  day  hour  PM2.5   PM10       SO2      NO2  CO       O3  \
# 3      2013      3    1     3    3.0    3.0    3.0000   2.0000 NaN      NaN
# 29     2013      3    2     5   15.0   18.0   42.2688  26.4837 NaN  56.1204
# 99     2013      3    5     3    NaN   51.0   13.0000  28.0000 NaN  91.0000
# 110    2013      3    5    14    NaN  146.0   84.0000  83.0000 NaN  91.0000
# 178    2013      3    8    10  173.0  193.0  105.3864  79.4511 NaN  68.0000
# ...     ...    ...  ...   ...    ...    ...       ...      ...  ..      ...
# 34879  2017      2   21     7    NaN    NaN       NaN      NaN NaN      NaN
# 34880  2017      2   21     8    NaN    NaN       NaN      NaN NaN      NaN
# 34883  2017      2   21    11    NaN    NaN       NaN      NaN NaN      NaN
# 34885  2017      2   21    13    NaN    NaN       NaN      NaN NaN      NaN
# 34934  2017      2   23    14    NaN    6.0       NaN  11.0000 NaN  99.0000
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM  station
# ...

# %%
huairou.dropna(subset=['CO', 'RAIN'], inplace=True)

# %%
huairou.CO.value_counts()
# Out:
# 300.0     3247
# 400.0     2915
# 500.0     2695
# 200.0     2382
# 600.0     2265
#           ...
# 9700.0       1
# 7299.0       1
# 3799.0       1
# 3899.0       1
# 8900.0       1
# Name: CO, Length: 108, dtype: int64

# %%
huairou.fillna(value="NaN", inplace=True)
huairou.isna().sum()
# Out:
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Kota Nongzhanguan

# %%
nong.drop(columns=['No'], inplace=True)
nong[nong.CO.isna()]
# Out:
#        year  month  day  hour  PM2.5   PM10     SO2      NO2  CO     O3  TEMP  \
# 27     2013      3    2     3    3.0    6.0    8.00   30.000 NaN   89.0  -3.1
# 123    2013      3    6     3  169.0  190.0  107.00  155.000 NaN   35.0   6.3
# 178    2013      3    8    10  216.0  233.0   78.54  151.922 NaN  102.0  19.9
# 219    2013      3   10     3   16.0   32.0    8.00   53.000 NaN   94.0  -0.9
# 315    2013      3   14     3   72.0   56.0   26.00   60.000 NaN   93.0  -0.7
# ...     ...    ...  ...   ...    ...    ...     ...      ...  ..    ...   ...
# 34958  2017      2   24    14    NaN    NaN     NaN      NaN NaN    NaN  11.2
# 34986  2017      2   25    18    NaN    NaN     NaN      NaN NaN    NaN  11.4
# 35006  2017      2   26    14    NaN    NaN     NaN      NaN NaN    NaN  12.4
# 35026  2017      2   27    10    NaN    NaN     NaN      NaN NaN    NaN   6.8
# 35042  2017      2   28     2    NaN    NaN     NaN      NaN NaN    NaN   8.6
#
# ...

# %%
nong.dropna(subset=['CO', 'RAIN'], inplace=True)

# %%
nong.CO.value_counts()
# Out:
# 300.0     2615
# 400.0     2476
# 500.0     2205
# 700.0     2197
# 600.0     2154
#           ...
# 5599.0       1
# 9900.0       1
# 9100.0       1
# 8800.0       1
# 9600.0       1
# Name: CO, Length: 115, dtype: int64

# %%
nong.fillna(value="NaN", inplace=True)
nong.isna().sum()
# Out:
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Kota Shunyi

# %%
shunyi.drop(columns=['No'], inplace=True)
shunyi[shunyi.CO.isna()]
# Out:
#        year  month  day  hour  PM2.5   PM10      SO2      NO2  CO    O3  TEMP  \
# 3      2013      3    1     3   12.0   12.0   3.0000   5.0000 NaN   NaN  -2.1
# 99     2013      3    5     3   98.0  116.0   5.0000   4.0000 NaN  84.0   0.5
# 120    2013      3    6     0  200.0  208.0  79.6824  97.7228 NaN  61.0   4.5
# 131    2013      3    6    11  164.0  174.0  87.1080  75.7557 NaN  61.0   9.1
# 178    2013      3    8    10  174.0  196.0  74.2560  62.6165 NaN  98.0  16.8
# ...     ...    ...  ...   ...    ...    ...      ...      ...  ..   ...   ...
# 34879  2017      2   21     7    NaN    NaN      NaN      NaN NaN   NaN  -2.5
# 34880  2017      2   21     8    NaN    NaN      NaN      NaN NaN   NaN  -2.1
# 34883  2017      2   21    11    NaN    NaN      NaN      NaN NaN   NaN  -0.2
# 34885  2017      2   21    13    NaN    NaN      NaN      NaN NaN   NaN  -0.1
# 34938  2017      2   23    18    9.0   21.0      NaN      NaN NaN  76.0   6.3
#
# ...

# %%
shunyi.dropna(subset=['CO', 'RAIN'], inplace=True)

# %%
shunyi.CO.value_counts()
# Out:
# 300.0     2872
# 400.0     2562
# 200.0     2280
# 500.0     2235
# 600.0     2132
#           ...
# 9800.0       1
# 4299.0       1
# 4799.0       1
# 4599.0       1
# 8200.0       1
# Name: CO, Length: 115, dtype: int64

# %%
shunyi.fillna(value="NaN", inplace=True)
shunyi.isna().sum()
# Out:
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Kota Tiantan

# %%
tiantan.drop(columns=['No'], inplace=True)
tiantan[tiantan.CO.isna()]
# Out:
#        year  month  day  hour  PM2.5   PM10       SO2       NO2  CO     O3  \
# 27     2013      3    2     3    9.0   10.0    8.0000   26.0000 NaN   83.0
# 123    2013      3    6     3  173.0  186.0   87.0000  122.0000 NaN   94.0
# 174    2013      3    8     6    NaN    NaN       NaN       NaN NaN  107.0
# 175    2013      3    8     7    NaN    NaN       NaN       NaN NaN  107.0
# 178    2013      3    8    10    NaN  373.0  116.2392  211.6643 NaN  107.0
# ...     ...    ...  ...   ...    ...    ...       ...       ...  ..    ...
# 35030  2017      2   27    14    NaN    NaN       NaN       NaN NaN    NaN
# 35031  2017      2   27    15    NaN    NaN       NaN       NaN NaN    NaN
# 35032  2017      2   27    16    NaN    NaN       NaN       NaN NaN    NaN
# 35057  2017      2   28    17    9.0   37.0       NaN       NaN NaN    NaN
# 35058  2017      2   28    18   15.0   43.0       NaN       NaN NaN    NaN
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM  station
# ...

# %%
tiantan.dropna(subset=['CO', 'RAIN'], inplace=True)

# %%
tiantan.CO.value_counts()
# Out:
# 400.0     2775
# 500.0     2552
# 600.0     2535
# 300.0     2434
# 700.0     2350
#           ...
# 9500.0       1
# 8900.0       1
# 6799.0       1
# 9600.0       1
# 5599.0       1
# Name: CO, Length: 117, dtype: int64

# %%
tiantan.fillna(value="NaN", inplace=True)
tiantan.isna().sum()
# Out:
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Kota Wanliu

# %%
wanliu.drop(columns=['No'], inplace=True)
wanliu[wanliu.CO.isna()]
# Out:
#        year  month  day  hour  PM2.5   PM10       SO2       NO2  CO    O3  \
# 3      2013      3    1     3   11.0   30.0    8.0000   14.0000 NaN   NaN
# 99     2013      3    5     3  129.0  179.0   61.0000   92.0000 NaN  60.0
# 176    2013      3    8     8  290.0  355.0   66.0000  127.0000 NaN  68.0
# 178    2013      3    8    10  277.0  360.0  122.2368  188.6707 NaN  68.0
# 195    2013      3    9     3  108.0  111.0   42.0000   77.0000 NaN  56.0
# ...     ...    ...  ...   ...    ...    ...       ...       ...  ..   ...
# 34879  2017      2   21     7    NaN    NaN       NaN       NaN NaN   NaN
# 34880  2017      2   21     8    NaN    NaN       NaN       NaN NaN   NaN
# 34883  2017      2   21    11    NaN    NaN       NaN       NaN NaN   NaN
# 34885  2017      2   21    13    NaN    NaN       NaN       NaN NaN   NaN
# 35029  2017      2   27    13   74.0  121.0       NaN   95.0000 NaN  31.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM station
# ...

# %%
wanliu.dropna(subset=['CO', 'RAIN'], inplace=True)

# %%
wanliu.CO.value_counts()
# Out:
# 600.0     2472
# 300.0     2418
# 700.0     2385
# 500.0     2226
# 400.0     2185
#           ...
# 6299.0       1
# 7299.0       1
# 6799.0       1
# 4299.0       1
# 7599.0       1
# Name: CO, Length: 120, dtype: int64

# %%
wanliu.fillna(value="NaN", inplace=True)
wanliu.isna().sum()
# Out:
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# Kota Wanshouxigong

# %%
wans.drop(columns=['No'], inplace=True)
wans[wans.CO.isna()]
# Out:
#        year  month  day  hour  PM2.5   PM10      SO2       NO2  CO    O3  \
# 3      2013      3    1     3    8.0    8.0    3.000   16.0000 NaN   NaN
# 99     2013      3    5     3  114.0  130.0    4.000   59.0000 NaN  87.0
# 178    2013      3    8    10  360.0  398.0  115.668  220.9028 NaN  94.0
# 195    2013      3    9     3   68.0   81.0    5.000   79.0000 NaN  86.0
# 291    2013      3   13     3    9.0    9.0    6.000   19.0000 NaN  54.0
# ...     ...    ...  ...   ...    ...    ...      ...       ...  ..   ...
# 35005  2017      2   26    13    NaN    NaN      NaN       NaN NaN   NaN
# 35027  2017      2   27    11    NaN    NaN      NaN       NaN NaN   NaN
# 35028  2017      2   27    12    NaN    NaN      NaN       NaN NaN   NaN
# 35029  2017      2   27    13    NaN    NaN      NaN       NaN NaN   NaN
# 35054  2017      2   28    14    3.0    6.0      NaN    5.0000 NaN  82.0
#
#        TEMP    PRES  DEWP  RAIN   wd  WSPM        station
# ...

# %%
wans.dropna(subset=['CO', 'RAIN'], inplace=True)

# %%
wans.CO.value_counts()
# Out:
# 300.0     2341
# 400.0     2226
# 700.0     2156
# 800.0     2121
# 500.0     2104
#           ...
# 4599.0       1
# 7599.0       1
# 8599.0       1
# 6099.0       1
# 4099.0       1
# Name: CO, Length: 116, dtype: int64

# %%
wans.fillna(value="NaN", inplace=True)
wans.isna().sum()
# Out:
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore
# Peningkatan CO per tahun dan pengaruh curah hujan untuk mengurangi polusi

# %% [markdown]
# Bagian ini berisikan hal-hal yang perlu dieksplor dari dataset sebelumnya.

# %% [markdown]
# Kota Aotizhongxin

# %%
aoti.describe(include="all")
# Out:
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %%
aoti.groupby(by="year").CO.nunique().sort_values(ascending=False)
# Out:
# year
# 2015    98
# 2016    93
# 2013    91
# 2017    90
# 2014    74
# Name: CO, dtype: int64

# %%
aoti.groupby(by="RAIN").CO.nunique().sort_values(ascending=False)
# Out:
# RAIN
# 0.0     113
# 0.1      42
# 0.2      36
# 0.3      28
# 0.4      26
#        ...
# 11.2      1
# 11.3      1
# 11.5      1
# 11.6      1
# 6.8       1
# Name: CO, Length: 128, dtype: int64

# %% [markdown]
# Kota Changping

# %%
changping.describe(include="all")
# Out:
#                 year         month           day          hour  PM2.5   PM10  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064  35064
# unique           NaN           NaN           NaN           NaN    482    563
# top              NaN           NaN           NaN           NaN    NaN    NaN
# freq             NaN           NaN           NaN           NaN    774    582
# mean     2014.662560      6.522930     15.729637     11.500000    NaN    NaN
# std         1.177213      3.448752      8.800218      6.922285    NaN    NaN
# min      2013.000000      1.000000      1.000000      0.000000    NaN    NaN
# 25%      2014.000000      4.000000      8.000000      5.750000    NaN    NaN
# 50%      2015.000000      7.000000     16.000000     11.500000    NaN    NaN
# 75%      2016.000000     10.000000     23.000000     17.250000    NaN    NaN
# max      2017.000000     12.000000     31.000000     23.000000    NaN    NaN
#
# ...

# %%
changping.groupby(by="year").CO.nunique().sort_values(ascending=False)
# Out:
# year
# 2015    94
# 2017    87
# 2016    85
# 2014    83
# 2013    82
# Name: CO, dtype: int64

# %%
changping.groupby(by="RAIN").CO.nunique().sort_values(ascending=False)
# Out:
# RAIN
# 0.0     116
# 0.2      35
# 0.1      34
# 0.3      29
# 0.7      24
#        ...
# 11.6      1
# 12.3      1
# 12.7      1
# 12.8      1
# 9.8       1
# Name: CO, Length: 117, dtype: int64

# %% [markdown]
# Kota Dingling

# %%
dingling.describe(include="all")
# Out:
#                   No          year         month           day          hour  \
# count   33001.000000  33001.000000  33001.000000  33001.000000  33001.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17977.147723   2014.721463      6.422836     15.799521     11.495743
# std     10005.430241      1.154093      3.441572      8.741853      6.932986
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      9704.000000   2014.000000      3.000000      8.000000      5.000000
# 50%     18180.000000   2015.000000      6.000000     16.000000     11.000000
# 75%     26550.000000   2016.000000      9.000000     23.000000     18.000000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %%
dingling.groupby(by="year").CO.nunique().sort_values(ascending=False)
# Out:
# year
# 2015    83
# 2016    81
# 2017    70
# 2014    56
# 2013    55
# Name: CO, dtype: int64

# %%
dingling.groupby(by="RAIN").CO.nunique().sort_values(ascending=False)
# Out:
# RAIN
# 0.0     103
# 0.2      35
# 0.1      32
# 0.3      27
# 0.5      23
#        ...
# 11.4      1
# 11.5      1
# 11.6      1
# 5.3       1
# 52.1      1
# Name: CO, Length: 113, dtype: int64

# %% [markdown]
# Kota Dongsi

# %%
dongsi.describe(include="all")
# Out:
#                   No          year         month           day          hour  \
# count   31847.000000  31847.000000  31847.000000  31847.000000  31847.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    18516.626558   2014.786165      6.387886     15.698402     11.500707
# std      9726.142279      1.118656      3.477471      8.826800      6.933734
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     10690.500000   2014.000000      3.000000      8.000000      5.000000
# 50%     18718.000000   2015.000000      6.000000     16.000000     11.000000
# 75%     26758.500000   2016.000000      9.000000     23.000000     18.000000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %%
dongsi.groupby(by="year").CO.nunique().sort_values(ascending=False)
# Out:
# year
# 2016    94
# 2015    93
# 2013    87
# 2017    85
# 2014    75
# Name: CO, dtype: int64

# %%
dongsi.groupby(by="RAIN").CO.nunique().sort_values(ascending=False)
# Out:
# RAIN
# 0.0     115
# 0.1      37
# 0.2      30
# 0.3      27
# 0.4      26
#        ...
# 11.1      1
# 11.2      1
# 11.4      1
# 11.8      1
# 46.4      1
# Name: CO, Length: 111, dtype: int64

# %% [markdown]
# Kota Guanyuan

# %%
guanyuan.describe(include="all")
# Out:
#                 year         month           day          hour  PM2.5   PM10  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064  35064
# unique           NaN           NaN           NaN           NaN    558    631
# top              NaN           NaN           NaN           NaN    NaN    NaN
# freq             NaN           NaN           NaN           NaN    616    429
# mean     2014.662560      6.522930     15.729637     11.500000    NaN    NaN
# std         1.177213      3.448752      8.800218      6.922285    NaN    NaN
# min      2013.000000      1.000000      1.000000      0.000000    NaN    NaN
# 25%      2014.000000      4.000000      8.000000      5.750000    NaN    NaN
# 50%      2015.000000      7.000000     16.000000     11.500000    NaN    NaN
# 75%      2016.000000     10.000000     23.000000     17.250000    NaN    NaN
# max      2017.000000     12.000000     31.000000     23.000000    NaN    NaN
#
# ...

# %%
guanyuan.groupby(by="year").CO.nunique().sort_values(ascending=False)
# Out:
# year
# 2015    100
# 2016     88
# 2013     84
# 2017     84
# 2014     75
# Name: CO, dtype: int64

# %%
guanyuan.groupby(by="RAIN").CO.nunique().sort_values(ascending=False)
# Out:
# RAIN
# 0.0     118
# 0.1      44
# 0.2      31
# 0.4      30
# 0.3      28
#        ...
# 10.6      1
# 11.2      1
# 11.3      1
# 11.5      1
# 6.8       1
# Name: CO, Length: 128, dtype: int64

# %% [markdown]
# Kota Gucheng

# %%
gucheng.describe(include="all")
# Out:
#                 year         month           day          hour    PM2.5  \
# count   33620.000000  33620.000000  33620.000000  33620.000000  33620.0
# unique           NaN           NaN           NaN           NaN    575.0
# top              NaN           NaN           NaN           NaN      8.0
# freq             NaN           NaN           NaN           NaN    543.0
# mean     2014.706157      6.461719     15.751933     11.508537      NaN
# std         1.160364      3.423001      8.860851      6.931029      NaN
# min      2013.000000      1.000000      1.000000      0.000000      NaN
# 25%      2014.000000      3.000000      8.000000      6.000000      NaN
# 50%      2015.000000      6.000000     16.000000     12.000000      NaN
# 75%      2016.000000      9.000000     23.000000     18.000000      NaN
# max      2017.000000     12.000000     31.000000     23.000000      NaN
#
#            PM10      SO2      NO2            CO       O3     TEMP     PRES  \
# ...

# %%
gucheng.groupby(by="year").CO.nunique().sort_values(ascending=False)
# Out:
# year
# 2015    93
# 2013    88
# 2016    86
# 2017    86
# 2014    79
# Name: CO, dtype: int64

# %%
gucheng.groupby(by="RAIN").CO.nunique().sort_values(ascending=False)
# Out:
# RAIN
# 0.0     116
# 0.1      35
# 0.2      35
# 0.3      27
# 0.4      23
#        ...
# 11.0      1
# 11.6      1
# 12.4      1
# 12.8      1
# 41.9      1
# Name: CO, Length: 125, dtype: int64

# %% [markdown]
# Kota Huairou

# %%
huairou.describe(include="all")
# Out:
#                 year         month           day          hour    PM2.5  \
# count   33587.000000  33587.000000  33587.000000  33587.000000  33587.0
# unique           NaN           NaN           NaN           NaN    479.0
# top              NaN           NaN           NaN           NaN      3.0
# freq             NaN           NaN           NaN           NaN   1015.0
# mean     2014.691458      6.531426     15.737101     11.547265      NaN
# std         1.168978      3.463490      8.815987      6.921207      NaN
# min      2013.000000      1.000000      1.000000      0.000000      NaN
# 25%      2014.000000      3.000000      8.000000      6.000000      NaN
# 50%      2015.000000      7.000000     16.000000     12.000000      NaN
# 75%      2016.000000     10.000000     23.000000     18.000000      NaN
# max      2017.000000     12.000000     31.000000     23.000000      NaN
#
#            PM10      SO2      NO2            CO       O3          TEMP  \
# ...

# %%
huairou.groupby(by="year").CO.nunique().sort_values(ascending=False)
# Out:
# year
# 2015    84
# 2017    79
# 2016    78
# 2013    62
# 2014    59
# Name: CO, dtype: int64

# %%
huairou.groupby(by="RAIN").CO.nunique().sort_values(ascending=False)
# Out:
# RAIN
# 0.0     108
# 0.1      35
# 0.4      31
# 0.2      29
# 0.3      24
#        ...
# 11.4      1
# 11.6      1
# 5.6       1
# 3.4       1
# 6.6       1
# Name: CO, Length: 128, dtype: int64

# %% [markdown]
# Nongzhanguan

# %%
nong.describe(include="all")
# Out:
#                 year         month           day          hour    PM2.5  \
# count   33838.000000  33838.000000  33838.000000  33838.000000  33838.0
# unique           NaN           NaN           NaN           NaN    556.0
# top              NaN           NaN           NaN           NaN      3.0
# freq             NaN           NaN           NaN           NaN    671.0
# mean     2014.681985      6.466901     15.676163     11.509605      NaN
# std         1.169183      3.435860      8.817111      6.933385      NaN
# min      2013.000000      1.000000      1.000000      0.000000      NaN
# 25%      2014.000000      3.000000      8.000000      6.000000      NaN
# 50%      2015.000000      6.000000     16.000000     11.000000      NaN
# 75%      2016.000000      9.000000     23.000000     18.000000      NaN
# max      2017.000000     12.000000     31.000000     23.000000      NaN
#
#            PM10      SO2      NO2            CO       O3          TEMP  \
# ...

# %%
nong.groupby(by="year").CO.nunique().sort_values(ascending=False)
# Out:
# year
# 2015    97
# 2013    94
# 2016    87
# 2017    86
# 2014    80
# Name: CO, dtype: int64

# %%
nong.groupby(by="RAIN").CO.nunique().sort_values(ascending=False)
# Out:
# RAIN
# 0.0     115
# 0.1      44
# 0.2      34
# 0.3      30
# 0.4      24
#        ...
# 11.4      1
# 11.8      1
# 12.1      1
# 6.3       1
# 46.4      1
# Name: CO, Length: 119, dtype: int64

# %% [markdown]
# Kota Shunyi

# %%
shunyi.describe(include="all")
# Out:
#                 year         month           day          hour    PM2.5  \
# count   32836.000000  32836.000000  32836.000000  32836.000000  32836.0
# unique           NaN           NaN           NaN           NaN    555.0
# top              NaN           NaN           NaN           NaN      3.0
# freq             NaN           NaN           NaN           NaN    771.0
# mean     2014.700664      6.501066     15.731453     11.631137      NaN
# std         1.161182      3.490512      8.793778      6.906454      NaN
# min      2013.000000      1.000000      1.000000      0.000000      NaN
# 25%      2014.000000      3.000000      8.000000      6.000000      NaN
# 50%      2015.000000      6.000000     16.000000     12.000000      NaN
# 75%      2016.000000     10.000000     23.000000     18.000000      NaN
# max      2017.000000     12.000000     31.000000     23.000000      NaN
#
#            PM10      SO2    NO2            CO       O3          TEMP  \
# ...

# %%
shunyi.groupby(by="year").CO.nunique().sort_values(ascending=False)
# Out:
# year
# 2015    95
# 2017    92
# 2013    88
# 2016    86
# 2014    69
# Name: CO, dtype: int64

# %%
shunyi.groupby(by="RAIN").CO.nunique().sort_values(ascending=False)
# Out:
# RAIN
# 0.0     115
# 0.1      36
# 0.2      33
# 0.5      28
# 0.3      26
#        ...
# 10.3      1
# 10.4      1
# 10.5      1
# 10.6      1
# 37.3      1
# Name: CO, Length: 112, dtype: int64

# %% [markdown]
# Kota Tiantan

# %%
tiantan.describe(include="all")
# Out:
#                 year         month           day          hour    PM2.5  \
# count   33918.000000  33918.000000  33918.000000  33918.000000  33918.0
# unique           NaN           NaN           NaN           NaN    533.0
# top              NaN           NaN           NaN           NaN      3.0
# freq             NaN           NaN           NaN           NaN    628.0
# mean     2014.683885      6.501002     15.698479     11.516451      NaN
# std         1.173543      3.432292      8.832785      6.932343      NaN
# min      2013.000000      1.000000      1.000000      0.000000      NaN
# 25%      2014.000000      4.000000      8.000000      6.000000      NaN
# 50%      2015.000000      7.000000     16.000000     12.000000      NaN
# 75%      2016.000000      9.000000     23.000000     18.000000      NaN
# max      2017.000000     12.000000     31.000000     23.000000      NaN
#
#            PM10      SO2      NO2            CO       O3          TEMP  \
# ...

# %%
tiantan.groupby(by="year").CO.nunique().sort_values(ascending=False)
# Out:
# year
# 2015    96
# 2013    91
# 2017    85
# 2016    83
# 2014    72
# Name: CO, dtype: int64

# %%
tiantan.groupby(by="RAIN").CO.nunique().sort_values(ascending=False)
# Out:
# RAIN
# 0.0     117
# 0.1      42
# 0.2      33
# 0.3      32
# 0.4      24
#        ...
# 11.4      1
# 11.8      1
# 12.1      1
# 5.8       1
# 46.4      1
# Name: CO, Length: 118, dtype: int64

# %% [markdown]
# Kota Wanliu

# %%
wanliu.describe(include="all")
# Out:
#                 year         month           day          hour    PM2.5  \
# count   33232.000000  33232.000000  33232.000000  33232.000000  33232.0
# unique           NaN           NaN           NaN           NaN    531.0
# top              NaN           NaN           NaN           NaN      3.0
# freq             NaN           NaN           NaN           NaN    654.0
# mean     2014.729086      6.401601     15.700078     11.515708      NaN
# std         1.150183      3.411283      8.853979      6.929814      NaN
# min      2013.000000      1.000000      1.000000      0.000000      NaN
# 25%      2014.000000      3.000000      8.000000      6.000000      NaN
# 50%      2015.000000      6.000000     16.000000     12.000000      NaN
# 75%      2016.000000      9.000000     23.000000     18.000000      NaN
# max      2017.000000     12.000000     31.000000     23.000000      NaN
#
#            PM10      SO2    NO2            CO       O3          TEMP  \
# ...

# %%
wanliu.groupby(by="year").CO.nunique().sort_values(ascending=False)
# Out:
# year
# 2013    102
# 2016    100
# 2015     91
# 2017     86
# 2014     81
# Name: CO, dtype: int64

# %%
wanliu.groupby(by="RAIN").CO.nunique().sort_values(ascending=False)
# Out:
# RAIN
# 0.0     120
# 0.1      38
# 0.2      27
# 0.3      27
# 0.4      25
#        ...
# 11.3      1
# 11.7      1
# 5.9       1
# 12.2      1
# 72.5      1
# Name: CO, Length: 125, dtype: int64

# %% [markdown]
# Kota Wanshouxigong

# %%
wans.describe(include="all")
# Out:
#                 year         month           day          hour    PM2.5  \
# count   33750.000000  33750.000000  33750.000000  33750.000000  33750.0
# unique           NaN           NaN           NaN           NaN    570.0
# top              NaN           NaN           NaN           NaN      3.0
# freq             NaN           NaN           NaN           NaN    687.0
# mean     2014.682815      6.536741     15.701185     11.508770      NaN
# std         1.167548      3.458229      8.817775      6.925189      NaN
# min      2013.000000      1.000000      1.000000      0.000000      NaN
# 25%      2014.000000      4.000000      8.000000      6.000000      NaN
# 50%      2015.000000      7.000000     16.000000     12.000000      NaN
# 75%      2016.000000     10.000000     23.000000     18.000000      NaN
# max      2017.000000     12.000000     31.000000     23.000000      NaN
#
#            PM10      SO2      NO2            CO       O3          TEMP  \
# ...

# %%
wans.groupby(by="year").CO.nunique().sort_values(ascending=False)
# Out:
# year
# 2013    99
# 2015    98
# 2016    88
# 2017    84
# 2014    79
# Name: CO, dtype: int64

# %%
wans.groupby(by="RAIN").CO.nunique().sort_values(ascending=False)
# Out:
# RAIN
# 0.0     116
# 0.1      37
# 0.2      32
# 0.3      30
# 0.4      26
#        ...
# 11.5      1
# 11.8      1
# 12.6      1
# 13.0      1
# 46.4      1
# Name: CO, Length: 118, dtype: int64

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:
# Kota manakah yang memiliki konsentrasi CO paling tinggi dan paling rendah pada 2017?

# %% [markdown]
# Bagian ini adalah tampilan chart dari pertanyaan 1 yang sudah divisualisasikan agar mempermudah proses pengambilan keputusan

# %% [markdown]
# Konsentrasi CO pada kota Aotizhongxin

# %%
df = pd.DataFrame(aoti)

# Mengelompokkan data berdasarkan tahun dan menghitung rata-rata CO di 2017
average_co_per_year = df.loc[df['year'] == 2017].groupby('year')['CO'].mean()

# Membuat plot untuk data rata-rata CO di 2017
plt.figure(figsize=(10, 6))
average_co_per_year.plot(kind='bar', color='skyblue')
plt.title('Rata-rata CO per Tahun pada Kota Aotizhongxin')
plt.xlabel('Tahun')
plt.ylabel('Rata-rata CO')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Konsentrasi CO pada kota Changping

# %%
df = pd.DataFrame(changping)

# Mengelompokkan data berdasarkan tahun dan menghitung rata-rata CO di 2017
average_co_per_year = df.loc[df['year'] == 2017].groupby('year')['CO'].mean()

# Membuat plot untuk data rata-rata CO di 2017
plt.figure(figsize=(10, 6))
average_co_per_year.plot(kind='bar', color='skyblue')
plt.title('Rata-rata CO per Tahun pada Kota Changping')
plt.xlabel('Tahun')
plt.ylabel('Rata-rata CO')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Konsentrasi CO pada kota Dingling

# %%
df = pd.DataFrame(dingling)

# Mengelompokkan data berdasarkan tahun dan menghitung rata-rata CO di 2017
average_co_per_year = df.loc[df['year'] == 2017].groupby('year')['CO'].mean()

# Membuat plot untuk data rata-rata CO di 2017
plt.figure(figsize=(10, 6))
average_co_per_year.plot(kind='bar', color='skyblue')
plt.title('Rata-rata CO per Tahun pada Kota Dingling')
plt.xlabel('Tahun')
plt.ylabel('Rata-rata CO')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Konsentrasi CO pada kota Dongsi

# %%
df = pd.DataFrame(dongsi)

# Mengelompokkan data berdasarkan tahun dan menghitung rata-rata CO di 2017
average_co_per_year = df.loc[df['year'] == 2017].groupby('year')['CO'].mean()

# Membuat plot untuk data rata-rata CO di 2017
plt.figure(figsize=(10, 6))
average_co_per_year.plot(kind='bar', color='skyblue')
plt.title('Rata-rata CO per Tahun pada Kota Dongsi')
plt.xlabel('Tahun')
plt.ylabel('Rata-rata CO')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Konsentrasi CO pada Kota Guanyuan

# %%
df = pd.DataFrame(guanyuan)

# Mengelompokkan data berdasarkan tahun dan menghitung rata-rata CO di 2017
average_co_per_year = df.loc[df['year'] == 2017].groupby('year')['CO'].mean()

# Membuat plot untuk data rata-rata CO di 2017
plt.figure(figsize=(10, 6))
average_co_per_year.plot(kind='bar', color='skyblue')
plt.title('Rata-rata CO per Tahun pada Kota Guanyuan')
plt.xlabel('Tahun')
plt.ylabel('Rata-rata CO')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Konsentrasi CO pada Kota Gucheng

# %%
df = pd.DataFrame(gucheng)

# Mengelompokkan data berdasarkan tahun dan menghitung rata-rata CO di 2017
average_co_per_year = df.loc[df['year'] == 2017].groupby('year')['CO'].mean()

# Membuat plot untuk data rata-rata CO di 2017
plt.figure(figsize=(10, 6))
average_co_per_year.plot(kind='bar', color='skyblue')
plt.title('Rata-rata CO per Tahun pada Kota Gucheng')
plt.xlabel('Tahun')
plt.ylabel('Rata-rata CO')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Konsentrasi CO pada Kota Huairou

# %%
df = pd.DataFrame(huairou)

# Mengelompokkan data berdasarkan tahun dan menghitung rata-rata CO di 2017
average_co_per_year = df.loc[df['year'] == 2017].groupby('year')['CO'].mean()

# Membuat plot untuk data rata-rata CO di 2017
plt.figure(figsize=(10, 6))
average_co_per_year.plot(kind='bar', color='skyblue')
plt.title('Rata-rata CO per Tahun pada Kota huairou')
plt.xlabel('Tahun')
plt.ylabel('Rata-rata CO')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Konsentrasi CO pada Kota Nongzhanguan

# %%
df = pd.DataFrame(nong)

# Mengelompokkan data berdasarkan tahun dan menghitung rata-rata CO di 2017
average_co_per_year = df.loc[df['year'] == 2017].groupby('year')['CO'].mean()

# Membuat plot untuk data rata-rata CO di 2017
plt.figure(figsize=(10, 6))
average_co_per_year.plot(kind='bar', color='skyblue')
plt.title('Rata-rata CO per Tahun pada Kota Nongzhanguan')
plt.xlabel('Tahun')
plt.ylabel('Rata-rata CO')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Konsentrasi CO pada Kota Shunyi

# %%
df = pd.DataFrame(shunyi)

# Mengelompokkan data berdasarkan tahun dan menghitung rata-rata CO di 2017
average_co_per_year = df.loc[df['year'] == 2017].groupby('year')['CO'].mean()

# Membuat plot untuk data rata-rata CO di 2017
plt.figure(figsize=(10, 6))
average_co_per_year.plot(kind='bar', color='skyblue')
plt.title('Rata-rata CO per Tahun pada Kota Shunyi')
plt.xlabel('Tahun')
plt.ylabel('Rata-rata CO')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Konsentrasi CO pada Kota Tiantan

# %%
df = pd.DataFrame(tiantan)

# Mengelompokkan data berdasarkan tahun dan menghitung rata-rata CO di 2017
average_co_per_year = df.loc[df['year'] == 2017].groupby('year')['CO'].mean()

# Membuat plot untuk data rata-rata CO di 2017
plt.figure(figsize=(10, 6))
average_co_per_year.plot(kind='bar', color='skyblue')
plt.title('Rata-rata CO per Tahun pada Kota Tiantan')
plt.xlabel('Tahun')
plt.ylabel('Rata-rata CO')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Konsentrasi CO pada Kota Wanliu

# %%
df = pd.DataFrame(wanliu)

# Mengelompokkan data berdasarkan tahun dan menghitung rata-rata CO di 2017
average_co_per_year = df.loc[df['year'] == 2017].groupby('year')['CO'].mean()

# Membuat plot untuk data rata-rata CO di 2017
plt.figure(figsize=(10, 6))
average_co_per_year.plot(kind='bar', color='skyblue')
plt.title('Rata-rata CO per Tahun pada Kota Wanliu')
plt.xlabel('Tahun')
plt.ylabel('Rata-rata CO')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# Konsentrasi CO pada Kota Wanshouxigong

# %%
df = pd.DataFrame(wans)

# Mengelompokkan data berdasarkan tahun dan menghitung rata-rata CO di 2017
average_co_per_year = df.loc[df['year'] == 2017].groupby('year')['CO'].mean()

# Membuat plot untuk data rata-rata CO di 2017
plt.figure(figsize=(10, 6))
average_co_per_year.plot(kind='bar', color='skyblue')
plt.title('Rata-rata CO per Tahun pada Kota Wanshouxigong')
plt.xlabel('Tahun')
plt.ylabel('Rata-rata CO')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
dfs = [aoti, changping, dingling, dongsi, guanyuan, gucheng, huairou, nong, shunyi, tiantan, wanliu, wans]

# Baca setiap dataset ke dalam DataFrame


# Gabungkan semua DataFrames menjadi satu DataFrame besar
combined_df = pd.concat(dfs, ignore_index=True)

# Mengelompokkan data berdasarkan tahun dan menghitung rata-rata CO per tahun
average_co_per_year = combined_df.groupby(['year', 'station'])['CO'].mean().unstack()

# Filter data untuk tahun 2017
average_co_2017 = average_co_per_year.loc[2017]

# Membuat plot untuk data rata-rata CO per tahun dengan warna yang berbeda untuk setiap kota
plt.figure(figsize=(14, 8))  # Menyesuaikan lebar dan tinggi grafik
average_co_2017.plot(kind='bar', color=['skyblue', 'lightgreen', 'lightcoral', 'gold', 'lightseagreen', 'violet', 'salmon', 'cyan', 'orange', 'pink', 'lightblue', 'lightyellow'])
plt.title('Rata-rata CO Tahun 2017 pada Berbagai Kota')
plt.xlabel('Kota')
plt.ylabel('Rata-rata CO')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ### Pertanyaan 2:
# Apakah konsentrasi curah hujan berpengaruh terhadap konsentrasi CO?

# %% [markdown]
# Bagian ini adalah tampilan chart dari pertanyaan 2 yang sudah divisualisasikan agar mempermudah proses pengambilan keputusan

# %% [markdown]
# Pengaruh Hujan terhadap Konsentrasi CO di Kota Aotizhongxin

# %%
df = pd.DataFrame(aoti)

# Membuat plot scatter untuk pengaruh hujan terhadap konsentrasi CO
plt.figure(figsize=(10, 6))
plt.scatter(df['RAIN'], df['CO'], color='blue')
plt.title('Pengaruh Hujan terhadap Konsentrasi CO di Kota Aotizhongxin')
plt.xlabel('Konsentrasi Hujan')
plt.ylabel('Konsentrasi CO')
plt.grid(True)
plt.show()

# %% [markdown]
# Pengaruh Hujan terhadap Konsentrasi CO di Kota Changping

# %%
df = pd.DataFrame(changping)

# Membuat plot scatter untuk pengaruh hujan terhadap konsentrasi CO
plt.figure(figsize=(10, 6))
plt.scatter(df['RAIN'], df['CO'], color='blue')
plt.title('Pengaruh Hujan terhadap Konsentrasi CO di Kota Changping')
plt.xlabel('Konsentrasi Hujan')
plt.ylabel('Konsentrasi CO')
plt.grid(True)
plt.show()

# %% [markdown]
# Pengaruh Hujan terhadap Konsentrasi CO di Kota Dingling

# %%
df = pd.DataFrame(dingling)

# Membuat plot scatter untuk pengaruh hujan terhadap konsentrasi CO
plt.figure(figsize=(10, 6))
plt.scatter(df['RAIN'], df['CO'], color='blue')
plt.title('Pengaruh Hujan terhadap Konsentrasi CO di Kota Dingling')
plt.xlabel('Konsentrasi Hujan')
plt.ylabel('Konsentrasi CO')
plt.grid(True)
plt.show()

# %% [markdown]
# Pengaruh Hujan terhadap Konsentrasi CO di Kota Dongsi

# %%
df = pd.DataFrame(dongsi)

# Membuat plot scatter untuk pengaruh hujan terhadap konsentrasi CO
plt.figure(figsize=(10, 6))
plt.scatter(df['RAIN'], df['CO'], color='blue')
plt.title('Pengaruh Hujan terhadap Konsentrasi CO di Kota Dongsi')
plt.xlabel('Konsentrasi Hujan')
plt.ylabel('Konsentrasi CO')
plt.grid(True)
plt.show()

# %% [markdown]
# Pengaruh Hujan terhadap Konsentrasi CO di Kota Guanyuan

# %%
df = pd.DataFrame(guanyuan)

# Membuat plot scatter untuk pengaruh hujan terhadap konsentrasi CO
plt.figure(figsize=(10, 6))
plt.scatter(df['RAIN'], df['CO'], color='blue')
plt.title('Pengaruh Hujan terhadap Konsentrasi CO di Kota Guanyuan')
plt.xlabel('Konsentrasi Hujan')
plt.ylabel('Konsentrasi CO')
plt.grid(True)
plt.show()

# %% [markdown]
# Pengaruh Hujan terhadap Konsentrasi CO di Kota Gucheng

# %%
df = pd.DataFrame(gucheng)

# Membuat plot scatter untuk pengaruh hujan terhadap konsentrasi CO
plt.figure(figsize=(10, 6))
plt.scatter(df['RAIN'], df['CO'], color='blue')
plt.title('Pengaruh Hujan terhadap Konsentrasi CO di Kota Gucheng')
plt.xlabel('Konsentrasi Hujan')
plt.ylabel('Konsentrasi CO')
plt.grid(True)
plt.show()

# %% [markdown]
# Pengaruh Hujan terhadap Konsentrasi CO di Kota Huairou

# %%
df = pd.DataFrame(huairou)

# Membuat plot scatter untuk pengaruh hujan terhadap konsentrasi CO
plt.figure(figsize=(10, 6))
plt.scatter(df['RAIN'], df['CO'], color='blue')
plt.title('Pengaruh Hujan terhadap Konsentrasi CO di Kota Huairou')
plt.xlabel('Konsentrasi Hujan')
plt.ylabel('Konsentrasi CO')
plt.grid(True)
plt.show()

# %% [markdown]
# Pengaruh Hujan terhadap Konsentrasi CO di Kota Nongzhanguan

# %%
df = pd.DataFrame(nong)

# Membuat plot scatter untuk pengaruh hujan terhadap konsentrasi CO
plt.figure(figsize=(10, 6))
plt.scatter(df['RAIN'], df['CO'], color='blue')
plt.title('Pengaruh Hujan terhadap Konsentrasi CO di Kota Nongzhanguan')
plt.xlabel('Konsentrasi Hujan')
plt.ylabel('Konsentrasi CO')
plt.grid(True)
plt.show()

# %% [markdown]
# Pengaruh Hujan terhadap Konsentrasi CO di Kota Shunyi

# %%
df = pd.DataFrame(shunyi)

# Membuat plot scatter untuk pengaruh hujan terhadap konsentrasi CO
plt.figure(figsize=(10, 6))
plt.scatter(df['RAIN'], df['CO'], color='blue')
plt.title('Pengaruh Hujan terhadap Konsentrasi CO di Kota Shunyi')
plt.xlabel('Konsentrasi Hujan')
plt.ylabel('Konsentrasi CO')
plt.grid(True)
plt.show()

# %% [markdown]
# Pengaruh Hujan terhadap Konsentrasi CO di Kota Tiantan

# %%
df = pd.DataFrame(tiantan)

# Membuat plot scatter untuk pengaruh hujan terhadap konsentrasi CO
plt.figure(figsize=(10, 6))
plt.scatter(df['RAIN'], df['CO'], color='blue')
plt.title('Pengaruh Hujan terhadap Konsentrasi CO di Kota Tiantan')
plt.xlabel('Konsentrasi Hujan')
plt.ylabel('Konsentrasi CO')
plt.grid(True)
plt.show()

# %% [markdown]
# Pengaruh Hujan terhadap Konsentrasi CO di Kota Wanliu

# %%
df = pd.DataFrame(wanliu)

# Membuat plot scatter untuk pengaruh hujan terhadap konsentrasi CO
plt.figure(figsize=(10, 6))
plt.scatter(df['RAIN'], df['CO'], color='blue')
plt.title('Pengaruh Hujan terhadap Konsentrasi CO di Kota Wanliu')
plt.xlabel('Konsentrasi Hujan')
plt.ylabel('Konsentrasi CO')
plt.grid(True)
plt.show()

# %% [markdown]
# Pengaruh Hujan terhadap Konsentrasi CO di Kota Wanshouxigong

# %%
df = pd.DataFrame(wans)

# Membuat plot scatter untuk pengaruh hujan terhadap konsentrasi CO
plt.figure(figsize=(10, 6))
plt.scatter(df['RAIN'], df['CO'], color='blue')
plt.title('Pengaruh Hujan terhadap Konsentrasi CO di Kota Wanshouxigong')
plt.xlabel('Konsentrasi Hujan')
plt.ylabel('Konsentrasi CO')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Bagian kesimpulan dari pertanyaan bisnis yang dicari kesimpulan atau solusinya berdasarkan dataset sebelumnya

# %% [markdown]
# - Conclution pertanyaan 1:
# Berdasarkan hasil dari visualisasi data yang diberikan, dapat dilihat kalau Kota Gucheng adalah kota yang memiliki konsentrasi CO paling tinggi pada 2017. Sedangkan kota yang memiliki konsentrasi CO paling rendah pada 2017 adalah Kota Dingling.
#
# - Conclution pertanyaan 2:
# Terjadi penurunan konsentrasi CO pada saat konsentrasi hujan sedang tinggi. Sehingga dapat ditarik kesimpulan kalau tingkat curah hujan berpengaruh terhadap konsentrasi CO di udara. Hal yang dapat diupayakan untuk menghindari peningkatan konsentrasi CO pada 2018 adalah membuat hujan buatan, dan juga mengimbau masyarakat di kota-kota untuk mengurangi penggunaan kendaraan bermotor dan beralih ke transportasi umum.
